# %%
# %pip install requests

# %% [markdown]
# **REQUESTS**

# %% [markdown]
# ***Resquisição simples, utilizando o metodo get***

# %%
from requests import get, post

# %%
resposta = get("https://pt.wikipedia.org/wiki/Hypertext_Transfer_Protocol")

# %%
resposta
# Out:
# <Response [200]>

# %% [markdown]
# ***O que foi devolvido***

# %%
#função help() ajuda a entender o objeto
help(resposta)
# Out:
# Help on Response in module requests.models object:
#
# class Response(builtins.object)
#  |  The :class:`Response <Response>` object, which contains a
#  |  server's response to an HTTP request.
#  |
#  |  Methods defined here:
#  |
#  |  __bool__(self)
#  |      Returns True if :attr:`status_code` is less than 400.
#  |
#  |      This attribute checks if the status code of the response is between
#  |      400 and 600 to see if there was a client error or a server error. If
#  |      the status code, is between 200 and 400, this will return True. This
#  |      is **not** a check to see if the response code is ``200 OK``.
#  |
#  |  __enter__(self)
#  |
#  |  __exit__(self, *args)
#  |
#  |  __getstate__(self)
#  |
#  |  __init__(self)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  __iter__(self)
#  |      Allows you to use a response as an iterator.
#  |
#  |  __nonzero__(self)
#  |      Returns True if :attr:`status_code` is less than 400.
# ...

# %%
#Os atributos text e ok 
resposta.text
# Out:
# '<!DOCTYPE html>\n<html class="client-nojs" lang="pt" dir="ltr">\n<head>\n<meta charset="UTF-8"/>\n<title>Hypertext Transfer Protocol – Wikipédia, a enciclopédia livre</title>\n<script>document.documentElement.className="client-js";RLCONF={"wgBreakFrames":false,"wgSeparatorTransformTable":[",\\t.","\xa0\\t,"],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","janeiro","fevereiro","março","abril","maio","junho","julho","agosto","setembro","outubro","novembro","dezembro"],"wgRequestId":"52180be7-f88c-4db4-acff-4939e322fee7","wgCSPNonce":false,"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":false,"wgNamespaceNumber":0,"wgPageName":"Hypertext_Transfer_Protocol","wgTitle":"Hypertext Transfer Protocol","wgCurRevisionId":62555291,"wgRevisionId":62555291,"wgArticleId":974,"wgIsArticle":true,"wgIsRedirect":false,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["!CS1 inglês-fontes em língua (en)","!CS1 manut: Nomes múltiplos: lista de
# ...

# %%
resposta.ok
# Out:
# True

# %% [markdown]
# ***WEB SCRAPIN AND WEB CRAWLER***

# %%
from requests import get
resposta = get("https://www.python.org/jobs/")

# %%
resposta.ok
# Out:
# True

# %% [markdown]
# ###utilizar a biblioteca html5lib como parser###
# ###Para navegar utilizaremos a beautiful soup###

# %%
# !pip install bs4
# Out:
# ...
#   Created wheel for bs4: filename=bs4-0.0.1-py3-none-any.whl size=1277 sha256=18742dbf862e903b6da274f45b4fd0587d9d0cbd0871621fca1d7e530feb79d8
#   Stored in directory: c:\users\gilma\appdata\local\pip\cache\wheels\75\78\21\68b124549c9bdc94f822c02fb9aa3578a669843f9767776bca
# Successfully built bs4
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install html5lib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Agora vamos utilizar o BeautifulSoup para mapear o conteudo do codigo html

# %%
from bs4 import BeautifulSoup

# %%
tags = BeautifulSoup(resposta.text, "html5lib")

# %%
help(tags) #sempre usar a função help() para extrair informações do objeto
# Out:
# Help on BeautifulSoup in module bs4 object:
#
# class BeautifulSoup(bs4.element.Tag)
#  |  BeautifulSoup(markup='', features=None, builder=None, parse_only=None, from_encoding=None, exclude_encodings=None, element_classes=None, **kwargs)
#  |
#  |  A data structure representing a parsed HTML or XML document.
#  |
#  |  Most of the methods you'll call on a BeautifulSoup object are inherited from
#  |  PageElement or Tag.
#  |
#  |  Internally, this class defines the basic interface called by the
#  |  tree builders when converting an HTML/XML document into a data
#  |  structure. The interface abstracts away the differences between
#  |  parsers. To write a new tree builder, you'll need to understand
#  |  these methods as a whole.
#  |
#  |  These methods will be called by the BeautifulSoup constructor:
#  |    * reset()
#  |    * feed(markup)
#  |
#  |  The tree builder may call these methods from its feed() implementation:
# ...

# %% [markdown]
#   Para começar vamos localizar a tag title

# %%
title = tags.find("title") #retorna a tag e a titulo especifico
title
# Out:
# <title>Python Job Board | Python.org</title>

# %%
title.text #busca sem a tag <title>
# Out:
# 'Python Job Board | Python.org'
